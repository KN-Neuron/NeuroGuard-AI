# %%
# %pip install numpy
# %pip install pandas
# %pip install mne
# Out:
# Requirement already satisfied: numpy in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (2.2.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dropt\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dropt\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting mne
#   Downloading mne-1.9.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in c:\users\dropt\appdata\roaming\python\python312\site-packages (from mne) (5.2.1)
# Collecting jinja2 (from mne)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting lazy-loader>=0.3 (from mne)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting matplotlib>=3.6 (from mne)
#   Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\dropt\appdata\local\programs\python\python312\lib\site-packages (from mne) (2.2.4)
# Requirement already satisfied: packaging in c:\users\dropt\appdata\roaming\python\python312\site-packages (from mne) (24.2)
# Collecting pooch>=1.5 (from mne)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting scipy>=1.9 (from mne)
#   Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting tqdm (from mne)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.6->mne)
#   Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.6->mne)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.6->mne)
#   Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl.metadata (104 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.6->mne)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.6->mne)
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.6->mne)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dropt\appdata\roaming\python\python312\site-packages (from matplotlib>=3.6->mne) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\dropt\appdata\roaming\python\python312\site-packages (from pooch>=1.5->mne) (4.3.7)
# Collecting requests>=2.19.0 (from pooch>=1.5->mne)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->mne)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: colorama in c:\users\dropt\appdata\roaming\python\python312\site-packages (from tqdm->mne) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\dropt\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mne) (1.17.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.5->mne)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.5->mne)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.5->mne)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.5->mne)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading mne-1.9.0-py3-none-any.whl (7.4 MB)
#    ---------------------------------------- 0.0/7.4 MB ? eta -:--:--
#    ---------------------------------------- 7.4/7.4 MB 57.0 MB/s eta 0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 70.9 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
#    ---------------------------------------- 0.0/40.9 MB ? eta -:--:--
#    ---------------- ----------------------- 17.3/40.9 MB 78.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.7/40.9 MB 72.2 MB/s eta 0:00:01
#    -------------------------------------- - 39.8/40.9 MB 66.8 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.9 MB 50.1 MB/s eta 0:00:01
#    ---------------------------------------- 40.9/40.9 MB 40.1 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 62.3 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 38.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, tqdm, scipy, pyparsing, pillow, MarkupSafe, lazy-loader, kiwisolver, idna, fonttools, cycler, contourpy, charset-normalizer, certifi, requests, matplotlib, jinja2, pooch, mne
# Successfully installed MarkupSafe-3.0.2 certifi-2025.1.31 charset-normalizer-3.4.1 contourpy-1.3.1 cycler-0.12.1 fonttools-4.57.0 idna-3.10 jinja2-3.1.6 kiwisolver-1.4.8 lazy-loader-0.4 matplotlib-3.10.1 mne-1.9.0 pillow-11.2.1 pooch-1.8.2 pyparsing-3.2.3 requests-2.32.3 scipy-1.15.2 tqdm-4.67.1 urllib3-2.4.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'c:\Users\dropt\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\dropt\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\dropt\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script mne.exe is installed in 'c:\Users\dropt\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import mne
import os
import sys

# %%
from EEGDataExtractor import EEGDataExtractor

# %%
DATASETS_FOLDER: str = "c:\\Users\\dropt\\artificial-intelligence\\eeg_lib\\data/datasets"
DATA_DIR = f"{DATASETS_FOLDER}/Kolory/"

extractor = EEGDataExtractor(data_dir=DATA_DIR)
eeg_df, participants_info = extractor.extract_dataframe()
# Out:
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/011595b1@1651.fif...
#     Range : 0 ... 207624 =      0.000 ...   830.496 secs
# Ready.
# Reading 0 ... 207624  =      0.000 ...   830.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/011595b1@1651.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/022e8467@1910.fif...
#     Range : 0 ... 212349 =      0.000 ...   849.396 secs
# Ready.
# Reading 0 ... 212349  =      0.000 ...   849.396 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/06f240e9@1215.fif...
#     Range : 0 ... 184624 =      0.000 ...   738.496 secs
# Ready.
# Reading 0 ... 184624  =      0.000 ...   738.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/022e8467@1910.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/06f240e9@1215.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/25d0bdb3@1318.fif...
#     Range : 0 ... 216624 =      0.000 ...   866.496 secs
# Ready.
# Reading 0 ... 216624  =      0.000 ...   866.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory
096 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/90441f44@1643.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/9e8bae0e@1828.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/b34b1427@0906.fif...
#     Range : 0 ... 201674 =      0.000 ...   806.696 secs
# Ready.
# Reading 0 ... 201674  =      0.000 ...   806.696 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# ...
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/d87e1bd3@1806.fif...
#     Range : 0 ... 201699 =      0.000 ...   806.796 secs
# Ready.
# Reading 0 ... 201699  =      0.000 ...   806.796 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e08138e2@1731.fif...
#     Range : 0 ... 207449 =      0.000 ...   829.796 secs
# Ready.
# Reading 0 ... 207449  =      0.000 ...   829.796 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/d87e1bd3@1806.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e08138e2@1731.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e283301e@1606.fif...
#     Range : 0 ... 219424 =      0.000 ...   877.696 secs
# Ready.
# Reading 0 ... 219424  =      0.000 ...   877.696 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e43a9f9f@0941.fif...
#     Range : 0 ... 253624 =      0.000 ...  1014.496 secs
# Ready.
# Reading 0 ... 253624  =      0.000 ...  1014.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e283301e@1606.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/e43a9f9f@0941.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/f82b5699@1757.fif...
#     Range : 0 ... 205174 =      0.000 ...   820.696 secs
# Ready.
# Reading 0 ... 205174  =      0.000 ...   820.696 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/fd8a3308@1135.fif...
#     Range : 0 ... 228724 =      0.000 ...   914.896 secs
# Ready.
# Reading 0 ... 228724  =      0.000 ...   914.896 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/f82b5699@1757.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/fd8a3308@1135.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# Opening raw data file c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/ffae50df@1712.fif...
#     Range : 0 ... 197099 =      0.000 ...   788.396 secs
# Ready.
# Reading 0 ... 197099  =      0.000 ...   788.396 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: [np.str_('blue'), np.str_('break'), np.str_('gray'), np.str_('green'), np.str_('red'), np.str_('yellow')]
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 751 original time points ...
# 0 bad epochs dropped
# c:\Users\dropt\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:54: RuntimeWarning: This filename (c:\Users\dropt\artificial-intelligence\eeg_lib\data/datasets/Kolory/ffae50df@1712.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)

# %%
eeg_df.head()["epoch"][0]
# Out:
# array([[ 1.59949059e-06,  4.66025978e-07, -2.15380011e-06, ...,
#          1.29476315e-06,  8.50347724e-07,  1.66841336e-06],
#        [ 1.61846220e-06,  1.19613053e-06,  1.29070086e-06, ...,
#          3.26989160e-06,  2.71957984e-06,  2.37409640e-06],
#        [-1.76377514e-05, -2.12479183e-05, -1.82417335e-05, ...,
#          2.06641293e-05,  2.82200662e-05,  3.94110464e-05],
#        [ 2.17844413e-05,  5.21727712e-06, -6.40627642e-06, ...,
#          1.53385355e-05,  2.48763533e-05,  2.15969502e-05]],
#       shape=(4, 751))

# %%
eeg_df.head()
# Out:
#   participant_id                                              epoch  label
# 0  011595b1@1651  [[1.5994905899983496e-06, 4.660259780289654e-0...   gray
# 1  011595b1@1651  [[3.2936710911247503e-06, 3.745427511069207e-0...  green
# 2  011595b1@1651  [[4.327731927482567e-06, 2.515285592381088e-06...   gray
# 3  011595b1@1651  [[1.7759480686267016e-06, -3.0099938072414544e...    red
# 4  011595b1@1651  [[4.0924612078715145e-06, 4.532130983695527e-0...   gray

# %%
eeg_df["epoch"][0].shape
# Out:
# (4, 751)
