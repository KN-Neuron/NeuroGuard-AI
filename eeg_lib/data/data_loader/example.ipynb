# %%
import pandas as pd
import numpy as np
import mne
import os

# %%
from eeg_lib.commons.constant import DATASETS_FOLDER
from EEGDataExtractor import EEGDataExtractor

# %%
DATA_DIR = f"{DATASETS_FOLDER}/Kolory/"

extractor = EEGDataExtractor(data_dir=DATA_DIR)
eeg_df, participants_info = extractor.extract_dataframe()

# %%
eeg_df.head()["epoch"][0].shape
# Out:
# (4, 751)

# %%
eeg_df.head()
# Out:
#   participant_id                                              epoch  label
# 0  46607ce4@1717  [[-9.24481589731569e-06, -9.598635937503012e-0...   gray
# 1  46607ce4@1717  [[-2.0148758591275883e-06, -1.1913500968321893...  green
# 2  46607ce4@1717  [[-1.7344745961061525e-07, 1.012701607648391e-...   gray
# 3  46607ce4@1717  [[4.047473978354836e-06, 2.417326642595136e-06...   blue
# 4  46607ce4@1717  [[-8.859812648227801e-06, -1.0092267325555332e...   gray

# %%
eeg_df["epoch"][0].shape
# Out:
# (4, 751)

# %%
len(participants_info)
# Out:
# 30

# %%
eeg_df["epoch"], eeg_df["participant_id"]
# Out:
# (0       [[-9.24481589731569e-06, -9.598635937503012e-0...
#  1       [[-2.0148758591275883e-06, -1.1913500968321893...
#  2       [[-1.7344745961061525e-07, 1.012701607648391e-...
#  3       [[4.047473978354836e-06, 2.417326642595136e-06...
#  4       [[-8.859812648227801e-06, -1.0092267325555332e...
#                                ...
#  6955    [[2.3088313361055115e-06, -3.3782038813997874e...
#  6956    [[3.5184575407039708e-06, 1.8381726793231112e-...
#  6957    [[-3.3741426285509895e-06, -2.25782683761941e-...
#  6958    [[-4.37930342530773e-06, -4.33262250492066e-06...
#  6959    [[2.3811832209304927e-05, 2.5132514940485573e-...
#  Name: epoch, Length: 6960, dtype: object,
#  0       46607ce4@1717
#  1       46607ce4@1717
#  2       46607ce4@1717
#  3       46607ce4@1717
#  4       46607ce4@1717
#              ...
#  6955    e08138e2@1731
#  6956    e08138e2@1731
#  6957    e08138e2@1731
#  6958    e08138e2@1731
#  6959    e08138e2@1731
#  Name: participant_id, Length: 6960, dtype: object)
