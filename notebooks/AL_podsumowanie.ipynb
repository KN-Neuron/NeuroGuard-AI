# %% [markdown]
# # AI-013 Podsumowanie dotychczasowej pracy- Adam Łaput

# %% [markdown]
# ## AI-001

# %% [markdown]
# ## AI-002

# %% [markdown]
# ## AI-003

# %% [markdown]
# ## AI-004

# %% [markdown]
# ## AI-005

# %% [markdown]
# ## AI-006

# %% [markdown]
# ## AI-007

# %% [markdown]
# ## AI-008

# %% [markdown]
# ## AI-009

# %% [markdown]
# ## AI-010

# %% [markdown]
# ## AI-011

# %% [markdown]
# ## AI-012
