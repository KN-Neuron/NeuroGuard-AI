# %% [markdown]
# # Notebook
# This notebook is used for running grid search on the EEGDataExtractor

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 2060
# Using device: cuda

# %%
import pandas as pd
import numpy as np
import mne
import os
import matplotlib.pyplot as plt

# %%
from eeg_lib.commons.constant import DATASETS_FOLDER
from eeg_lib.data.data_loader.EEGDataExtractor import EEGDataExtractor

# %%
from eeg_lib.utils.engine import create_user_profiles

# %%
from eeg_lib.utils.helpers import compute_genuine_imposter_distances, compute_threshold_metrics, compute_f1_vs_threshold, split_test_data_for_verification

# %%
from eeg_lib.utils.visualisations import plot_distance_distribution_on_ax, plot_threshold_metrics, plot_f1_vs_threshold, plot_distance_distribution_return, plot_f1_vs_threshold_return, plot_threshold_metrics_return

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.manifold import TSNE
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

from matplotlib.colors import ListedColormap

# %%
from sklearn.model_selection import ParameterGrid

# %%
import torch.nn as nn

# %%
from eeg_lib.data.data_loader.TDNNFeatures import extract_features, extract_psd_features
from eeg_lib.data.TDNNDataset import TDNNDataset, get_dataset
from eeg_lib.models.verification.XVector import XVectorEmbeddingModel
from eeg_lib.losses.ProxyNCALoss import ProxyNCALoss
from eeg_lib.utils.visualisations import plot_tsne
from eeg_lib.utils.visualisations import create_handles
from eeg_lib.utils.helpers import split_train_test
from eeg_lib.models.similarity.centroids import SimilarityCentroidsVerifier, get_accuracy

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
from torch.optim.lr_scheduler import StepLR, ExponentialLR, ReduceLROnPlateau

# %%
from eeg_lib.models.verification.XVector import get_ecapa_model, get_standard_model, pretrain, fine_tune, create_embeddings, fine_tune_arcface

# %% [markdown]
# Grid to search over

# %%
grid = {
    "lfreq": [7.0],
    "hfreq": [20.0,50.0,75.0,100.0,150.0],
    "tmin": [0.0],
    "tmax": [5.0],
    "notch_filter": [[50]]
}

# %%
results = []

# %%
JSON_FILE_NAME = "eeg_extractor_grid_search_v4.json"

# %%
DATA_DIR = f"{DATASETS_FOLDER}/Kolory/"

# %% [markdown]
# Some pretested reasonable hyperparameters for the model itself

# %%
hparams = {
    "batch_size" : 64,
    "softmax_learning_rate" : 0.001,
    "proxy_learning_rate" : 0.001,
    "softmax_epochs" : 70,
    "proxy_epochs" : 100,
    "softmax_learning_rate_decay" : 0.95,
    "proxy_learning_rate_decay" : 0.95,
    "augmentation" : True,
    "std" : 0.02,
    "embedding_dim" : 256,
    "dropout_rate" : 0.25,
    "scale" : 10,
    "margin" : 0.1,
    "layer1_filters" : 512,
    "layer2_filters" : 512,
    "layer3_filters" : 1024,
    "layer4_filters" : 1024,
    "layer5_filters" : 1500,
    "layer_1_dilatation" : 1,
    "layer_2_dilatation" : 2,
    "layer_3_dilatation" : 3,
    "layer_1_stride" : 1,
    "layer_2_stride" : 1,
    "layer_3_stride" : 2,
    "no_norm" : True
}

# %%
def preprocess_data(eeg_df, test_size=0.2, random_state=42):
    X_train_tmp, X_test_tmp, y_train_tmp, y_test_tmp = split_train_test(eeg_df=eeg_df,test_size=test_size, random_state=random_state)
    epoch_length = X_train_tmp[0].shape[1]
    div, mod = divmod(epoch_length, 50)
    print(div)
    print(mod)
    
    # print(epoch_length)
    # print(epoch_length%50)
    truncated_length = div*50
    print(truncated_length)
    
    extracted_X_train = []
    for epoch in X_train_tmp:
        extracted_X_train.append(extract_features(epoch, fs=250, trunc=truncated_length).T)
    extracted_X_test = []        
    for epoch in X_test_tmp:
        extracted_X_test.append(extract_features(epoch, fs=250,trunc=truncated_length).T)
    le_train = LabelEncoder()
    le_train.fit(y_train_tmp)
    y_train_encoded = le_train.transform(y_train_tmp)
    
    le_test = LabelEncoder()
    le_test.fit(y_test_tmp)
    y_test_encoded = le_test.transform(y_test_tmp)
    X_train = np.array(extracted_X_train)
    X_test = np.array(extracted_X_test)
    scalers = {}
    X_train_norm = np.empty_like(X_train)
    X_test_norm = np.empty_like(X_test)
    # scaling per feature
    for f in range(X_train.shape[1]):
        scalers[f] = StandardScaler().fit(X_train[:, f, :])
        X_train_norm[:, f, :] = scalers[f].transform(X_train[:, f, :])
        X_test_norm[:, f, :] = scalers[f].transform(X_test[:, f, :])
    return X_train_norm, y_train_encoded, X_test_norm, y_test_encoded

# %% [markdown]
# here we track:
# - the parameters used
# - the model's final loss
# - centroid_train_acc
# - centroid_test_acc,
# - final_train_acc
# - final_train_eer
# - final_train_f1
# - final_test_acc
# - final_test_f1
# - final_test_eer
#
# with the most important ones being:
# - final loss
# - final test acc
# - final test f1
# - final test eer

# %%
for run_idx, params in enumerate(ParameterGrid(grid), start=1):
    print(f"RUN NUMBER: {run_idx}")
    print("Parameters: ", params)
    extractor = EEGDataExtractor(
        data_dir=DATA_DIR,
        lfreq=params['lfreq'],
        hfreq=params['hfreq'],
        tmin=params['tmin'],
        tmax=params['tmax'],
        notch_filter=params['notch_filter']
    )
    
    
    eeg_df, participant_info = extractor.extract_dataframe()
    X_train_norm, y_train_encoded, X_test_norm, y_test_encoded = preprocess_data(eeg_df=eeg_df)
    
    num_train_classes = len(np.unique(y_train_encoded))
    
    train_loader = get_dataset(hparams,X_train_norm, y_train_encoded)
    model = pretrain(hparams, device, X_train_norm.shape[1], num_train_classes, train_loader, None, "ECAPA2").to(device)
    model, final_loss = fine_tune_arcface(model, hparams, device, train_loader, num_train_classes, None, return_final_loss=True)
    model = model.to("cpu")
    
    embd_train, embd_test = create_embeddings(model, X_train_norm, X_test_norm,hparams)
    centroid_train_acc, centroid_test_acc = get_accuracy(embd_train, embd_test, y_train_encoded, y_test_encoded)
    user_profiles = create_user_profiles(embd_train, np.array(y_train_encoded))
    genuine_dists, imposter_dists = compute_genuine_imposter_distances(
        embeddings=embd_train ,
        ids=np.array(y_train_encoded),
        user_profiles=user_profiles,
        distance_metric="cosine"
    )
    
    (
        thresholds, fnr_list, fpr_list, acc_list,
        best_T, best_fnr, best_fpr, best_acc
    ) = compute_threshold_metrics(genuine_dists, imposter_dists, num_thresholds=200)
    
    thresholds, f1_list, best_T, best_f1 = compute_f1_vs_threshold(
    genuine_dists, imposter_dists, num_thresholds=300
    )
    # test
    profile_embd, profile_ids, verify_embd, verify_ids = split_test_data_for_verification(
        embd_test, np.array(y_test_encoded), profile_ratio=0.6
    )
    
    test_user_profiles = create_user_profiles(profile_embd, profile_ids)
    
    genuine_dists, imposter_dists = compute_genuine_imposter_distances(
    embeddings=verify_embd,
    ids=verify_ids,
    user_profiles=test_user_profiles,
    distance_metric="cosine"
    )
        
    (
        test_thresholds, test_fnr_list, test_fpr_list, test_acc_list,
        test_best_T, test_best_fnr, test_best_fpr, test_best_acc
    ) = compute_threshold_metrics(genuine_dists, imposter_dists, num_thresholds=200)
    
    test_thresholds_f1, test_f1_list, test_best_T_f1, test_best_f1 = compute_f1_vs_threshold(
    genuine_dists, imposter_dists, num_thresholds=300
    )
    
    results.append({
        "params": params,
        "final_loss": final_loss,
        "centroid_train_acc": centroid_train_acc,
        "centroid_test_acc": centroid_test_acc,
        "final_train_acc": best_acc,
        "final_train_eer": best_fnr, 
        "final_train_f1": best_f1,
        "final_test_acc": test_best_acc,
        "final_test_f1": test_best_f1,
        "final_test_eer": test_best_fnr
    })
with open(JSON_FILE_NAME, "w") as f:
    json.dump(results, f, indent=2)
# Out:
# RUN NUMBER: 1
# Parameters:  {'hfreq': 20.0, 'lfreq': 7.0, 'notch_filter': [50], 'tmax': 5.0, 'tmin': 0.0}
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/011595b1@1651.fif...
#     Range : 0 ... 207624 =      0.000 ...   830.496 secs
# Ready.
# Reading 0 ... 207624  =      0.000 ...   830.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/011595b1@1651.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/022e8467@1910.fif...
#     Range : 0 ... 212349 =      0.000 ...   849.396 secs
# Ready.
# Reading 0 ... 212349  =      0.000 ...   849.396 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/022e8467@1910.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 1 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/06f240e9@1215.fif...
#     Range : 0 ... 184624 =      0.000 ...   738.496 secs
# Ready.
# Reading 0 ... 184624  =      0.000 ...   738.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/06f240e9@1215.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/25d0bdb3@1318.fif...
#     Range : 0 ... 216624 =      0.000 ...   866.496 secs
# Ready.
# Reading 0 ... 216624  =      0.000 ...   866.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/25d0bdb3@1318.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/2718372d@1400.fif...
#     Range : 0 ... 206649 =      0.000 ...   826.596 secs
# Ready.
# Reading 0 ... 206649  =      0.000 ...   826.596 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/2718372d@1400.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/2882ae26@1441.fif...
#     Range : 0 ... 198649 =      0.000 ...   794.596 secs
# Ready.
# Reading 0 ... 198649  =      0.000 ...   794.596 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/2882ae26@1441.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/3033b74a@1626.fif...
#     Range : 0 ... 200824 =      0.000 ...   803.296 secs
# Ready.
# Reading 0 ... 200824  =      0.000 ...   803.296 secs...
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/3033b74a@1626.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/36eea4bb@1519.fif...
#     Range : 0 ... 244074 =      0.000 ...   976.296 secs
# Ready.
# Reading 0 ... 244074  =      0.000 ...   976.296 secs...
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/36eea4bb@1519.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/39285860@1825.fif...
#     Range : 0 ... 193174 =      0.000 ...   772.696 secs
# Ready.
# Reading 0 ... 193174  =      0.000 ...   772.696 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/39285860@1825.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/446b3735@1618.fif...
#     Range : 0 ... 196549 =      0.000 ...   786.196 secs
# Ready.
# Reading 0 ... 196549  =      0.000 ...   786.196 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 7 - 20 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/446b3735@1618.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 7.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.00 Hz)
# - Upper passband edge: 20.00 Hz
# - Upper transition bandwidth: 5.00 Hz (-6 dB cutoff frequency: 22.50 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Used Annotations descriptions: ['blue', 'break', 'gray', 'green', 'red', 'yellow']
# Not setting metadata
# 232 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 232 events and 1251 original time points ...
# 0 bad epochs dropped
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory
# [Pretrain] Epoch 42/70  Loss=0.0186  Acc=0.9932
# [Pretrain] Epoch 43/70  Loss=0.0140  Acc=0.9959
# [Pretrain] Epoch 44/70  Loss=0.0122  Acc=0.9953
# [Pretrain] Epoch 45/70  Loss=0.0111  Acc=0.9971
# [Pretrain] Epoch 46/70  Loss=0.0138  Acc=0.9946
# [Pretrain] Epoch 47/70  Loss=0.0131  Acc=0.9968
# [Pretrain] Epoch 48/70  Loss=0.0130  Acc=0.9959
# [Pretrain] Epoch 49/70  Loss=0.0138  Acc=0.9957
# [Pretrain] Epoch 50/70  Loss=0.0076  Acc=0.9977
# [Pretrain] Epoch 51/70  Loss=0.0070  Acc=0.9978
# [Pretrain] Epoch 52/70  Loss=0.0064  Acc=0.9989
# [Pretrain] Epoch 53/70  Loss=0.0052  Acc=0.9987
# [Pretrain] Epoch 54/70  Loss=0.0066  Acc=0.9984
# [Pretrain] Epoch 55/70  Loss=0.0076  Acc=0.9978
# [Pretrain] Epoch 56/70  Loss=0.0070  Acc=0.9975
# [Pretrain] Epoch 57/70  Loss=0.0076  Acc=0.9978
# [Pretrain] Epoch 58/70  Loss=0.0078  Acc=0.9975
# [Pretrain] Epoch 59/70  Loss=0.0052  Acc=0.9987
# [Pretrain] Epoch 60/70  Loss=0.0059  Acc=0.9987
# [Pretrain] Epoch 61/70  Loss=0.0032  Acc=0.9995
# [Pretrain] Epoch 62/70  Loss=0.0047  Acc=0.9987
# [Pretrain] Epoch 63/70  Loss=0.0039  Acc=0.9995
# [Pretrain] Epoch 64/70  Loss=0.0049  Acc=0.9986
# [Pretrain] Epoch 65/70  Loss=0.0039  Acc=0.9993
# [Pretrain] Epoch 66/70  Loss=0.0051  Acc=0.9989
# [Pretrain] Epoch 67/70  Loss=0.0046  Acc=0.9989
# [Pretrain] Epoch 68/70  Loss=0.0046  Acc=0.9987
# [Pretrain] Epoch 69/70  Loss=0.0034  Acc=0.9993
# [Pretrain] Epoch 70/70  Loss=0.0031  Acc=0.9989
# [ArcFace Fine‑tune] Epoch 1/100  Loss=1.1097
# [ArcFace Fine‑tune] Epoch 2/100  Loss=0.3401
# [ArcFace Fine‑tune] Epoch 3/100  Loss=0.2402
# [ArcFace Fine‑tune] Epoch 4/100  Loss=0.2012
# [ArcFace Fine‑tune] Epoch 5/100  Loss=0.1708
# [ArcFace Fine‑tune] Epoch 6/100  Loss=0.1191
# [ArcFace Fine‑tune] Epoch 7/100  Loss=0.0821
# [ArcFace Fine‑tune] Epoch 8/100  Loss=0.0854
# [ArcFace Fine‑tune] Epoch 9/100  Loss=0.0844
# [ArcFace Fine‑tune] Epoch 10/100  Loss=0.0607
# [ArcFace Fine‑tune] Epoch 11/100  Loss=0.0480
# [ArcFace Fine‑tune] Epoch 12/100  Loss=0.0361
# [ArcFace Fine‑tune] Epoch 13/100  Loss=0.0352
# [ArcFace Fine‑tune] Epoch 14/100  Loss=0.0321
# [ArcFace Fine‑tune] Epoch 15/100  Loss=0.0249
# [ArcFace Fine‑tune] Epoch 16/100  Loss=0.0176
# [ArcFace Fine‑tune] Epoch 17/100  Loss=0.0182
# [ArcFace Fine‑tune] Epoch 18/100  Loss=0.0215
# [ArcFace Fine‑tune] Epoch 19/100  Loss=0.0289
# [ArcFace Fine‑tune] Epoch 20/100  Loss=0.0342
# [ArcFace Fine‑tune] Epoch 21/100  Loss=0.0193
# [ArcFace Fine‑tune] Epoch 22/100  Loss=0.0215
# [ArcFace Fine‑tune] Epoch 23/100  Loss=0.0243
# [ArcFace Fine‑tune] Epoch 24/100  Loss=0.0088
# [ArcFace Fine‑tune] Epoch 25/100  Loss=0.0098
# [ArcFace Fine‑tune] Epoch 26/100  Loss=0.0075
# [ArcFace Fine‑tune] Epoch 27/100  Loss=0.0187
# [ArcFace Fine‑tune] Epoch 28/100  Loss=0.0134
# [ArcFace Fine‑tune] Epoch 29/100  Loss=0.0076
# [ArcFace Fine‑tune] Epoch 30/100  Loss=0.0070
# [ArcFace Fine‑tune] Epoch 31/100  Loss=0.0068
# [ArcFace Fine‑tune] Epoch 32/100  Loss=0.0053
# [ArcFace Fine‑tune] Epoch 33/100  Loss=0.0070
# [ArcFace Fine‑tune] Epoch 34/100  Loss=0.0048
# [ArcFace Fine‑tune] Epoch 35/100  Loss=0.0073
# [ArcFace Fine‑tune] Epoch 36/100  Loss=0.0052
# [ArcFace Fine‑tune] Epoch 37/100  Loss=0.0047
# [ArcFace Fine‑tune] Epoch 38/100  Loss=0.0056
# [ArcFace Fine‑tune] Epoch 39/100  Loss=0.0038
# [ArcFace Fine‑tune] Epoch 40/100  Loss=0.0028
# [ArcFace Fine‑tune] Epoch 41/100  Loss=0.0028
# [ArcFace Fine‑tune] Epoch 42/100  Loss=0.0030
# [ArcFace Fine‑tune] Epoch 43/100  Loss=0.0057
# [ArcFace Fine‑tune] Epoch 44/100  Loss=0.0025
# [ArcFace Fine‑tune] Epoch 45/100  Loss=0.0029
# [ArcFace Fine‑tune] Epoch 46/100  Loss=0.0083
# [ArcFace Fine‑tune] Epoch 47/100  Loss=0.0035
# [ArcFace Fine‑tune] Epoch 48/100  Loss=0.0033
# [ArcFace Fine‑tune] Epoch 49/100  Loss=0.0048
# [ArcFace Fine‑tune] Epoch 50/100  Loss=0.0034
# [ArcFace Fine‑tune] Epoch 51/100  Loss=0.0021
# [ArcFace Fine‑tune] Epoch 52/100  Loss=0.0035
# [ArcFace Fine‑tune] Epoch 53/100  Loss=0.0039
# [ArcFace Fine‑tune] Epoch 54/100  Loss=0.0025
# [ArcFace Fine‑tune] Epoch 55/100  Loss=0.0030
# [ArcFace Fine‑tune] Epoch 56/100  Loss=0.0048
# [ArcFace Fine‑tune] Epoch 57/100  Loss=0.0025
# [ArcFace Fine‑tune] Epoch 58/100  Loss=0.0026
# [ArcFace Fine‑tune] Epoch 59/100  Loss=0.0025
# [ArcFace Fine‑tune] Epoch 60/100  Loss=0.0021
# [ArcFace Fine‑tune] Epoch 61/100  Loss=0.0026
# [ArcFace Fine‑tune] Epoch 62/100  Loss=0.0028
# [ArcFace Fine‑tune] Epoch 63/100  Loss=0.0031
# [ArcFace Fine‑tune] Epoch 64/100  Loss=0.0025
# [ArcFace Fine‑tune] Epoch 65/100  Loss=0.0022
# [ArcFace Fine‑tune] Epoch 66/100  Loss=0.0022
# [ArcFace Fine‑tune] Epoch 67/100  Loss=0.0020
# [ArcFace Fine‑tune] Epoch 68/100  Loss=0.0032
# [ArcFace Fine‑tune] Epoch 69/100  Loss=0.0023
# [ArcFace Fine‑tune] Epoch 70/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 71/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 72/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 73/100  Loss=0.0020
# [ArcFace Fine‑tune] Epoch 74/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 75/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 76/100  Loss=0.0020
# [ArcFace Fine‑tune] Epoch 77/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 78/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 79/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 80/100  Loss=0.0020
# [ArcFace Fine‑tune] Epoch 81/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 82/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 83/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 84/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 85/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 86/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 87/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 88/100  Loss=0.0020
# [ArcFace Fine‑tune] Epoch 89/100  Loss=0.0019
# [ArcFace Fine‑tune] Epoch 90/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 91/100  Loss=0.0017
# [ArcFace Fine‑tune] Epoch 92/100  Loss=0.0017
# [ArcFace Fine‑tune] Epoch 93/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 94/100  Loss=0.0018
# [ArcFace Fine‑tune] Epoch 95/100  Loss=0.0017
# [ArcFace Fine‑tune] Epoch 96/100  Loss=0.0023
# [ArcFace Fine‑tune] Epoch 97/100  Loss=0.0029
# [ArcFace Fine‑tune] Epoch 98/100  Loss=0.0016
# [ArcFace Fine‑tune] Epoch 99/100  Loss=0.0017
# [ArcFace Fine‑tune] Epoch 100/100  Loss=0.0017
# RUN NUMBER: 5
# Parameters:  {'hfreq': 150.0, 'lfreq': 7.0, 'notch_filter': [50], 'tmax': 5.0, 'tmin': 0.0}
# Opening raw data file C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/011595b1@1651.fif...
#     Range : 0 ... 207624 =      0.000 ...   830.496 secs
# Ready.
# Reading 0 ... 207624  =      0.000 ...   830.496 secs...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:53: RuntimeWarning: This filename (C:\Users\JS\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib/data/datasets/Kolory/011595b1@1651.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   eeg = mne.io.read_raw_fif(file_path, preload=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 14
#       3 print("Parameters: ", params)
#       4 extractor = EEGDataExtractor(
#       5     data_dir=DATA_DIR,
#       6     lfreq=params['lfreq'],
#    (...)     10     notch_filter=params['notch_filter']
#      11 )
# ---> 14 eeg_df, participant_info = extractor.extract_dataframe()
#      15 X_train_norm, y_train_encoded, X_test_norm, y_test_encoded = preprocess_data(eeg_df=eeg_df)
#      17 num_train_classes = len(np.unique(y_train_encoded))
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:88, in EEGDataExtractor.extract_dataframe(self)
#      82 def extract_dataframe(self) -> Tuple[pd.DataFrame, List[Dict[str, Any]]]:
#      83     """
#      84     Iterates over each participant's data, extracts each epoch as a numpy array,
#      85     and returns a DataFrame with columns: participant_id, epoch, label.
#      86     Also returns a list of participants with metadata.
#      87     """
# ---> 88     eeg_and_events, participants = self._load_eeg()
#      89     data = []
#      90     for item in eeg_and_events:
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\eeg_lib\data\data_loader\EEGDataExtractor.py:57, in EEGDataExtractor._load_eeg(self)
#      55 # Convert units (from µV to V if needed)
#      56 eeg.apply_function(lambda x: x * 10**-6)
# ---> 57 eeg.filter(l_freq=self.lfreq, h_freq=self.hfreq)
#      58 eeg.notch_filter(self.notch_filter)
#      59 events, event_id = mne.events_from_annotations(eeg)
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\venv\Lib\site-packages\mne\io\base.py:1174, in BaseRaw.filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#    1155 @copy_doc(FilterMixin.filter)
#    1156 def filter(
#    1157     self,
#    (...)   1172     verbose=None,
#    1173 ):
# -> 1174     return super().filter(
#    1175         l_freq,
#    1176         h_freq,
#    1177         picks,
#    1178         filter_length,
#    1179         l_trans_bandwidth,
#    1180         h_trans_bandwidth,
#    1181         n_jobs=n_jobs,
#    1182         method=method,
#    1183         iir_params=iir_params,
#    1184         phase=phase,
#    1185         fir_window=fir_window,
#    1186         fir_design=fir_design,
#    1187         skip_by_annotation=skip_by_annotation,
#    1188         pad=pad,
#    1189         verbose=verbose,
#    1190     )
#
# File <decorator-gen-87>:12, in filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\venv\Lib\site-packages\mne\filter.py:2562, in FilterMixin.filter(self, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, phase, fir_window, fir_design, skip_by_annotation, pad, verbose)
#    2558 for si, (start, stop) in enumerate(zip(onsets, ends)):
#    2559     # Only output filter params once (for info level), and only warn
#    2560     # once about the length criterion (longest segment is too short)
#    2561     use_verbose = verbose if si == max_idx else "error"
# -> 2562     filter_data(
#    2563         self._data[:, start:stop],
#    2564         s_freq,
#    2565         l_freq,
#    2566         h_freq,
#    2567         picks,
#    2568         filter_length,
#    2569         l_trans_bandwidth,
#    2570         h_trans_bandwidth,
#    2571         n_jobs,
#    2572         method,
#    2573         iir_params,
#    2574         copy=False,
#    2575         phase=phase,
#    2576         fir_window=fir_window,
#    2577         fir_design=fir_design,
#    2578         pad=pad,
#    2579         verbose=use_verbose,
#    2580     )
#    2581 # update info if filter is applied to all data channels/vertices,
#    2582 # and it's not a band-stop filter
#    2583 if not isinstance(self, _BaseSourceEstimate):
#
# File <decorator-gen-82>:12, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\venv\Lib\site-packages\mne\filter.py:1012, in filter_data(data, sfreq, l_freq, h_freq, picks, filter_length, l_trans_bandwidth, h_trans_bandwidth, n_jobs, method, iir_params, copy, phase, fir_window, fir_design, pad, verbose)
#    1010 data = _check_filterable(data)
#    1011 iir_params, method = _check_method(method, iir_params)
# -> 1012 filt = create_filter(
#    1013     data,
#    1014     sfreq,
#    1015     l_freq,
#    1016     h_freq,
#    1017     filter_length,
#    1018     l_trans_bandwidth,
#    1019     h_trans_bandwidth,
#    1020     method,
#    1021     iir_params,
#    1022     phase,
#    1023     fir_window,
#    1024     fir_design,
#    1025 )
#    1026 if method in ("fir", "fft"):
#    1027     data = _overlap_add_filter(data, filt, None, phase, picks, n_jobs, copy, pad)
#
# File <decorator-gen-83>:12, in create_filter(data, sfreq, l_freq, h_freq, filter_length, l_trans_bandwidth, h_trans_bandwidth, method, iir_params, phase, fir_window, fir_design, verbose)
#
# File ~\Desktop\Neuron\NeuroGuard\artificial-intelligence\venv\Lib\site-packages\mne\filter.py:1177, in create_filter(data, sfreq, l_freq, h_freq, filter_length, l_trans_bandwidth, h_trans_bandwidth, method, iir_params, phase, fir_window, fir_design, verbose)
#    1175     h_freq = np.array(h_freq, float).ravel()
#    1176     if (h_freq > (sfreq / 2.0)).any():
# -> 1177         raise ValueError(
#    1178             f"h_freq ({h_freq}) must be less than the Nyquist frequency "
#    1179             f"{sfreq / 2.0}"
#    1180         )
#    1181 if l_freq is not None:
#    1182     l_freq = np.array(l_freq, float).ravel()
#
# ValueError: h_freq ([150.]) must be less than the Nyquist frequency 125.0
